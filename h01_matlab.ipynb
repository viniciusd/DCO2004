% %% [markdown]
% # Hands-on 01: Tutorial de apresentação e uso básico do Matlab

% %% [markdown]
% # Objetivos
% As metas desse tutorial são ajudar o usuário a:
% - Apresentar vantagens de usar o Matlab;
% - Apresentar onde encontrar informações sobre o Matlab;
% - Apresentar o processo de Debug do Matlab;
% - Apresentar operações básicas com o Matlab.

% %% [markdown]
% # Matlab: O que é, vantagens e desvantagens

% %% [markdown]
% O nome MATLAB significa **Matrix Laboratory**. O MATLAB é um pacote de software para utilização em atividades científicas e de engenharia. Ele resolve problemas utilizando análise numérica e matricial, podendo apresentar soluções gráficas com a mesma facilidade das apresentadas pelas soluções analíticas.
%
% A principal ideia do MATLAB é servir como uma ferramenta de prototipagem rápida por software, habilitando o usuário a **conceber a ideia** pela manhã, **prototipar** durante a tarde, **simular** durante a noite e ter alguma **ideia do desempenho** no dia seguinte.
%
% Além de servir para o processo de prototipagem puramente em software (**simulação**), o Matlab tem interfaces para dispositivos como FPGAs, DSPs e plataformas de Rádio Definido Por Software, possibilitando embarcar códigos feitos em Matlab em dispositivos reais.

% %% [markdown]
% O desenvolvedor do Matlab é a Mathworks (http://www.mathworks.com).
% ![fig_mathworks_logo](./FIGS/HD_01_MATLAB/mathworks_logo.png)
%
% O distribuidor no Brasil é o OpenCadd: (http://www.opencadd.com.br)
% ![fig_mathworks_logo](./FIGS/HD_01_MATLAB/opencadd_logo.png)

% %% [markdown]
% ## Famílias de produtos do Matlab
%
% Mais de 100 produtos (https://www.mathworks.com/products/pfo.html):
%
% ![fig_matlab_family](./FIGS/HD_01_MATLAB/matlab_family.png)
%
% Para ver exemplos diversos de funcionalidades do Matlab consulte: https://www.mathworks.com/examples/product-family/matlab

% %% [markdown]
% ## Programar em Matlab é:
% - Usar (**modificar**) inúmeras funções escritas pelos usuários, por você mesmo e pela mathworks;
% - Usar **interfaces** com outras linguagens, softwares e hardwares específicos (se necessário);
% - Usar **Built-in Functions**: funções com código escondido (geralmente escritas em C++) que são parte do código base do Matlab ou de toolboxes.
%
% [Fonte: Introduction to Matlab](http://www.slideshare.net/ashishmeet/introduction-to-matlab-18425069)

% %% [markdown]
% ### Principais vantagens
% - Fácil de aprender a programar (linguagem de alto nível);
% - Facilidade de manipulação gráfica (2D, 3D, imagem, vídeo);
% - Código otimizado para realizar operações matriciais;
% - Fácil identificação de erros (bugs);
% - Vasta biblioteca de comandos (toolboxes);
% - Implementação mais fácil e rápida.
%
% ###  Principais desvantagens
% - Desempenho em termos de tempo de processamento é inferior quando comparado a aplicações em C++ (linguagem interpretada);
% - Má programação deixa o código muito lento (tempo de execução): o desempenho do código depende muito da programação ser baseada em operações matriciais (**não se deve programar like-C**);
% - Laços de concatenados geralmente são extremamente lentos.

% %% [markdown]
% ## Onde achar material sobre Matlab
%
% A Opencadd disponibiliza seminários gratuitos na internet (em Inglês e Português):
% https://www.opencadd.com.br/category/webinar/
%
% ![fig_opencadd_webnaar_logo](./FIGS/HD_01_MATLAB/opencadd_webnaar_logo.png)
%
% Existe uma infinidade de material gratuito na Matlab Central: http://www.mathworks.com/matlabcentral/
%
% O prof. Vicente Sousa tem um minicurso sobre Matlab que explora suas funcionalidades básicas em problemas gerais (não necessariamente de telecom). O material está disponível em:
%
% - **Parte 1: Apresentação e Introdução ao Ambiente do Matlab**
% Introdução ao Matlab; Descrição do ambiente gráfico e formas de acesso e manipulação
% de arquivos do Matlab; Comandos básicos; Comandos de acesso rápido aos recursos do
% Matlab; Números complexos, forma exponencial e cartesiana, módulo e fase
%  - [Download Slides](./MATERIAL/HD_01_MATLAB/Mini_Matlab_Extensao_Parte_1.pdf)
%  - [Download Códigos dos exercícios](./MATERIAL/HD_01_MATLAB/parte_1_exercicios.zip)
%
% - **Parte 2: Operação com Matrizes e Vetores**
% Polinômios; Demonstração de técnicas de manipulação de vetores. Declaração, módulo,
% exponenciação, divisão e manipulação de elementos de um vetor; Demonstração de
% técnicas de manipulação de matrizes; Declaração de matrizes simples e complexas,
% adição, multiplicação e divisão; Matriz transposta, inversa, escalonamento, autovetores
% e autovalores, exponenciação e matriz de funções).
%  - [Download Slides](./MATERIAL/HD_01_MATLAB/Mini_Matlab_Extensao_Parte_2.pdf)
%  - [Download Códigos dos exercícios](./MATERIAL/HD_01_MATLAB/parte_2_exercicios.zip)
%
% - **Parte 3: Controle de fluxo no Matlab, Gráficos e GUI**
% Controle de fluxo no Matlab (Controle por laços; Controle de fluxo encadeado); Gráficos
% bidimensionais; gerenciamento dos elementos gráficos no Matalb; Gráficos
% bidimensionais muito úteis para Engenharia; Gráficos tridimensionais.; interface gráfica
% do usuário; matlab compiler; Toolboxes; Otimização de códigos em Matlab.
%  - [Download Slides](./MATERIAL/HD_01_MATLAB/Mini_Matlab_Extensao_Parte_3.pdf)
%  - [Download Códigos dos exercícios](./MATERIAL/HD_01_MATLAB/parte_3_exercicios.zip)
%
% O aluno **Marcial Guerra de Medeiros** fez um guia rápido para criação de interface gráfica do usuário (GUI) usando Matlab. O material é bem didático e de fácil acompanhamento.
%
%  - [ENGATINHANDO NO GUI DO MATLAB OU COMO APRENDER A CRIAR INTERFACES GRÁFICAS NO MATLAB EM UMA TARDE](./MATERIAL/HD_01_MATLAB/MGM - Apostila GUI Matlab v1-1.pdf)
%  - [Download Códigos da GUI](./MATERIAL/HD_01_MATLAB/exemplo_GUI.zip)

% %% [markdown]
% ## Interface de desenvolvimento
%
% O Matlab tem uma IDE (*Integrated Development Environment*) que facilita muito a vida do programador. Entre algumas facilidades pordemos destacar:
% - Ambiente gráfico atrativo e funcional que minimiza a necessidade de uso de linhas de comando;
% - Ambiente de *MATLAB Code Analyzer Report* (indicação de potenciais bugs) e *profiling* de código integrado (indicação de melhoramentos para reduzir tempo de execução);
% - Facilidade de gestão e visualização de variáveis (inclusive vetores e matrizes);
% - Visualização e navegação no diretório de trabalho;
% - Rico ambiente de depuração (debug).
%
% O ambiente de desenvolvimento é similar ao apresentado a seguir:
% ![fig_slide13](./FIGS/HD_01_MATLAB/slide13.png)
%
% O acesso a funções, seus protótipos, modo de usar e uma explicação técnica sobre as mesmas podem ser encontrados facilmente.
%
% ![fig_slide14](./FIGS/HD_01_MATLAB/slide14.png)
% ![fig_slide15](./FIGS/HD_01_MATLAB/slide15.png)
%
% Também é possível acessar vídeos com diversos demos. Estão disponíveis desde cursos básicos sobre como programar em Matlab até vídeos sobre como usar os toolboxes avançados.
%
% ![fig_slide16](./FIGS/HD_01_MATLAB/slide16.png)
% ![fig_slide17](./FIGS/HD_01_MATLAB/slide17.png)

% %% [markdown]
% ## Tipos de arquivos do Matlab
%
% Existem basicamente dos arquivos a serem manipulados corriqueiramente no Matlab:
% - **Arquivos .MAT**: Arquivos com conteúdo das variáveis
%  - Economiza recursos de processamento e espaço de memória;
%  - Importante para guardar resultados para cálculos futuros;
%  - Para salvar o conteúdo use o comando *save*, enquanto que para recuperar, o comando *load*.
% - **Arquivos .m**: podem ser do tipo função ou script
%  - Tipo função: definição de uma função para tratamento de variáveis locais;
%    - **Nome**: nome_da_função.m (primeira linha é a definição do protótipo da função, a qual deve receber o mesmo nome do arquivo .m)
%  - Tipo script: sequência de comandos MATLAB que manipulam as variáveis do workspace (sem argumentos);
%    - **nome**: qualquer_nome.m
%
% **MUITO IMPORTANTE:** não colocar espaços em nomes de scripts e funções !!!

% %% [markdown]
% ### Exemplo de função
%
% Suponha que salvamos o código abaixo em um arquivo chamado **handson1_1.m**.
%
% >```bash
% function y = handson1_1(x, y)
% % Realiza a soma x + y
% y=x+y;
% ```
%
% Para chamar a função, basta digitar no **Command Window** do Matlab:
% >```bash
% handson1_1(9, 13)
% ```
%
% ans =
% 22
%
% Você ainda por chamar o help na função para ver sua descrição (tudo que está comentado depois da descrição da função será mostrado):
%
% >```bash
% help soma
% ```
%
% Realiza a soma x + y

% %% [markdown]
% ### Exemplo de script
% Um script é simplesmente um conjunto de chamadas de funções (ou outros scripts) em sequência. Por exemplo, suponha que salvamos o código abaixo em um arquivo chamado **handson1_2.m**:

% %%
x = 1;
s = 2;
s + x
% Out:
% ans =
%
%      3

% %% [markdown]
% Para chamar o script, digite no *Command Window* do Matlab:
%
% >```bash
% handson2_2
% ```
%
% ans =
% 3
%
% **Obs.:** Scritps podem chamar funções ou outros scripts, por exemplo:
%
% >```bash
% x = 1;
% s = 2;
% handson1_1(x, s)
% ```

% %% [markdown]
% ### Prática 01: Ambiente de edição

% %% [markdown]
% **Passo 1**: Abra um ambiente de edição (acesso ao ambiente de edição e criação de arquivo **.m**):
% ![fig_slide18_1](./FIGS/HD_01_MATLAB/slide18_1.png)
%
% **Passo 2**: O ambiente de edição e debug será aberto
% ![fig_slide18_2](./FIGS/HD_01_MATLAB/slide18_2.png)
%
%
% **Passo 3**: É possível visualizar a área de edição e o Menu de debug
% ![fig_slide19.png](./FIGS/HD_01_MATLAB/slide19.png)
%
% **Passo 4**: Insira o seguinte código no ambiente de edição e salve o arquivo com o nome **handson1_3.m** (você pode executar o código via Jupyter Notebook com o Kernel do Matlab concetado).

% %%
clear all;
t = 1:10;
f = 10;
s = cos(2*pi*f*t);
z = s + cos(2*pi*0.5*f*t);
chDisplays = ['O valor máximo de s é ' num2str(max(s))];
disp(chDisplays);
chDisplayz = ['O valor máximo de z é ' num2str(max(z))];
disp(chDisplayz);
% Out:
% O valor máximo de s é 1
% O valor máximo de z é 2

% %% [markdown]
% ![fig_slide20.png](./FIGS/HD_01_MATLAB/slide20.png)
%
% **Passo 5**: execute o arquivo via *commad window*, digitando handson1_3:
% ![fig_slide21](./FIGS/HD_01_MATLAB/slide21.png)
%
% **Passo 6**: Visualize as variáveis criadas pelo seu programa através do workspace;
%
% **Passo 7**: Visualize o tipo de cada variável criada pelo seu programa (execute o comando whos);
%
% **Passo 8 (Para relatório):** relate sobre os tipos de variáveis do Matlab (descrição e propósito) e crie um script exemplificando cada tipo. Procure material na internet. Essa é uma etapa muito importante para você aumentar sua familiaridade com os tipos de "containers" estão disponíveis no Matlab.
%
% **Passo 9**: Execute novamente o arquivo, agora via editor.
% ![fig_slide22_1](./FIGS/HD_01_MATLAB/slide22_1.png)
%
% **Passo 10**: Verifique no *Command Window* uma segunda execução do seu programa:
% ![fig_slide22_2](./FIGS/HD_01_MATLAB/slide22_2.png)

% %% [markdown]
% ## Interface de  debug (depuração): Você sabe o que é debug (depuração)?
% ![fig_slide23_2](./FIGS/HD_01_MATLAB/slide23_2.png)

% %% [markdown]
% **Depuração (debugging, debug)** é o processo de encontrar erros em um software. Erros de software incluem aqueles que previnem o programa de ser executado e aqueles que produzem um resultado inesperado! Por definição o processo de debug visa identificar um erro de software, mas é usual se depurar um código como uma etapa de teste, ou até mesmo, na pŕopria etapa de codificação.
%
% **Não rode agora**, mas ao rodar um programa em modo de debug, a seguinte tela será mostrada:
%
% ![fig_slide24](./FIGS/HD_01_MATLAB/slide24.png)
%
% O menu debug tem as seguintes funcionalidades:
% ![fig_slide25](./FIGS/HD_01_MATLAB/slide25.png)

% %% [markdown]
% ### Prática 02: Ambiente de depuração (debug)

% %% [markdown]
% **Passo 1**: Insira um breakpoint na linha 5 do código **handson1_3.m**. Uma bolinha vermelha indicará se o breakpoint foi inserido. Existem pelo menos três maneiras para isso:
% 1. Dois cliques na seta ao lado do número da linha;
% 2. Por meio da opção Set/Clear do ícone Breakpoints do Menu Principal;
% 3. Por meio da tecla de atalho F12.
%
% ![fig_slide26](./FIGS/HD_01_MATLAB/slide26.png)
%
% **Passo 2**: Execute novamente o arquivo **handson1_3.m** via editor (tecla F5)
% ![fig_slide27](./FIGS/HD_01_MATLAB/slide27.png)
%
% O código foi executado até a linha do breakpoint, uma seta verde indica a linha atual de execução do código.
% ![fig_slide28](./FIGS/HD_01_MATLAB/slide28.png)
%
%
% **Passo 3**(**Para relatório**)**:** evidencie com figuras quais variáveis foram criadas com a execução do programa no passo 3. Indique o tipo de cada variável.

% %% [markdown]
% ### Prática 03: Tempo de execução com uso de laço e com operação matricial
%
% O Matlab é otimizado para trabalhar com matrizes (e vetores). Assim, algumas operações devem ser vetorizadas ou matricializadas, evitando laços.
%
% Vamos escrever um código para criação de um mapa de cobertura de dois roteadores sem fio. A ideia é calcular a potência recebida em dBm para pontos equidistantes de 5 em 5 metros em uma área de cobertura de 200 por 200 m. A seguintes especificações devem ser obedecidas:
%
% 1. Os roteadores devem ser posicionados no meio do grid em relação a abscissa. Em relação ao eixo das ordenadas, o primeiro e segundo roteador deve ficar a 20% e a 80% da dimensão vertical da área de cobertura, respectivamente;
% 2. A potência de transmissão do roteador deve ser $P_T$ = 1 W;
% 3. Considere somente perda de percurso como manifestação de canal. Assim, a potência recebida ($P_R$) pode ser calculada como $P_R = P_T/d^4$, sendo $d$ a distância entre o roteador e o ponto de recepção.
%
% A figura a seguir ilustra o sistema.
% ![fig_slide30](./FIGS/HD_01_MATLAB/slide30.png)
%
% Vamos escrever o código com e sem laço FOR, ilustrando duas boas práticas em programação com o Matlab:
% 1. Evitar usar laços FOR em MATLAB; e
% 2. Usar operações eficientes com vectores/matrizes.
%
% **Passo 01:** Inspecione e execute in line (via Jupyter Notebook, apertando **Shift+Enter**) ou insira o código a seguir no editor do Matlab (salve com o nome **handson1_4.m**):

% %%
% limpa variáveis, a tela e fecha todos os gráficos existentes
clear all;clc;close all; 
dPasso = 5;                             % Resolução do grid
dDim = 200;                             % Dimensão do grid
nl = (dDim-2*dPasso)/dPasso + 1;        % Número de pontos de medição
%% Código com laço FOR
t1 = tic;                               % Abre um contador de tempo identificado por t1
% Matriz com posição de cada ponto do grid (posição relativa ao canto inferior direito)
for il = 1:nl 
    for ic = 1:nl
        px(il,ic) = dPasso + (ic-1)*dPasso;
        py(ic,il) = px(il,ic);
    end
end
% Matrizes de posição e potência recebida
for il = 1:nl
    for ic = 1:nl
        % Matrizes com posição de cada ponto do grid relativa a cada roteador
        pbs0(il,ic) = px(il,ic) + j*py(il,ic) - ( dDim/2 + 0.8*dDim*j); % Roteador 0
        pbs1(il,ic) = px(il,ic) + j*py(il,ic) - ( dDim/2 + 0.2*dDim*j); % Roteador 1
        % Cálculo da potência recebida em cada ponto do grid, recebida de cada roteador
        pl0(il,ic) = 10*log10(1/abs(pbs0(il,ic))^4/1e-3); % Roteador 0
        pl1(il,ic) = 10*log10(1/abs(pbs1(il,ic))^4/1e-3); % Roteador 1
        % cálculo da melhor potência em cada ponto do grid
        plf(il,ic) = max(pl0(il,ic), pl1(il,ic));
    end
end
tempoComFor = toc(t1); % Fecha contador de tempo e guarda tempo na variável tempoComFor
disp(['Tempo com Laço FOR = ' num2str(tempoComFor)]);   % Mostra tempo de execuçao do código
%% Gráficos para código com laço for
% Plota as posiçoes dos pontos do grid para os dois roteadores
subplot(1,2,1); plot(pbs0,'k.'); title('Roteador 0 com Laço');
subplot(1,2,2); plot(pbs1,'k.'); title('Roteador 1 com Laço');
figure;
% Plota a mapa de cores relativo a potência para os dois roteadores separadamente
subplot(1,2,1); pcolor(pl0); title('Roteador 0 com Laço');
subplot(1,2,2); pcolor(pl1); title('Roteador 1 com Laço');
figure;
% Plota a mapa de cores realtivo a melhor potência em cada ponto do grid (melhor entre os dois roteadores)
pcolor(plf);title(['Sistema com Laço - tempo ' num2str(tempoComFor)]);
% Out:
% Tempo com Laço FOR = 0.028554

% %% [markdown]
% **A execução do código resulta em:**
% 1. Mostrar o tempo necessário para executar o código (excluindo o processamento gráfico);
% 2. Gráficos com posição dos pontos do grid para os dois roteadores (roteador 0 e roteador 1). Note que o ponto (0,0) de cada roteador (de cada gráfico), i.e. seu posicionamento, é diferente. No roteador 0, o ponto (0,0) está a 80% do máximo valor vertical e, no roteador 1, o ponto (0,0) está a 20% do máximo, como espeficado na prática.
% 3. Gráficos com o mapa de cobertura (potência recebida em cada ponto do grid) para cada roteador separadamente;
% 4. Gráfico com o mapa de cobertura para melhor situação possível, i.e., a melhor potência recebida em cada ponto do grid (melhor entre os dois roteadores).
%
%
% ** Analise o código com cuidado. Tente compreender a modelagem e a sintaxe usada. Discuta com os colegas e com o professor. Faça um debug usando a IDE do Matlab.**
%
%
% Se você tiver problema com a plotagem do gráfico de pontos na IDE do Matlab, use
%
% ```python
% subplot(1,2,1); plot(pbs0,'ko'); title('Roteador 0 com Laço');
% subplot(1,2,2); plot(pbs1,'ko'); title('Roteador 1 com Laço');
% ```
%
% ao invés de
%
% ```python
% subplot(1,2,1); plot(pbs0,'k.'); title('Roteador 0 com Laço');
% subplot(1,2,2); plot(pbs1,'k.'); title('Roteador 1 com Laço');
% ```
% E maximize a figura gerada.

% %% [markdown]
% **Passo 02:** Agora vamos fazer o mesmo código anterior sem usar laço FOR. Execute in line (via Jupyter Notebook) ou insira o código a seguir no editor do Matlab (salve com o nome **handson1_5.m**):

% %%
clear all;clc;close all;
dPasso = 5;                          % Resolução do grid
dDim = 200;                          % Dimensão do grid
nl = (dDim-2*dPasso)/dPasso + 1;     % Número de pontos de medição
%% Código sem Laço
t2 = tic;                            % Abre um contador de tempo identificado por t2
% Matriz com posição de cada ponto do grid (posição relativa ao canto inferior direito)
[px,py] = meshgrid(dPasso:dPasso:dDim-dPasso, dPasso:dPasso:dDim-dPasso);
% Matrizes com posição de cada ponto do grid relativa a cada BS
pbs0SF = px + j*py - ( dDim/2 + 0.8*dDim*j);
pbs1SF = px + j*py - ( dDim/2 + 0.2*dDim*j);
% Cálculo da potência recebida em cada roteador
pl0SF = 10*log10(1./(abs(pbs0SF).^4)/1e-3);
pl1SF = 10*log10(1./(abs(pbs1SF).^4)/1e-3);
% Cálculo da melhor potência e cada ponto do grid
plfSF = max(pl0SF,pl1SF);
tempoSemFor = toc(t2); % fecha contador de tempo e guarda tempo na variável tempoComFor
disp(['Tempo sem Laço FOR = ' num2str(tempoSemFor)]); % Mostra tempo de execuçao do código
%% Gráficos para código com e sem laços for
% Plota as posiçoes dos pontos do grid para os dois roteadores
subplot(1,2,1); plot(pbs0SF,'ko');title('Roteador 0 sem Laço');
subplot(1,2,2); plot(pbs1SF,'ko');title('Roteador 1 sem Laço');
figure;
% Plota a mapa de cores relativo a potência para os dois roteadores separadamente
subplot(1,2,1); pcolor(pl0SF);title('Roteador 0 sem Laço');
subplot(1,2,2); pcolor(pl1SF);title('Roteador 1 sem Laço');
figure;
% Plota a mapa de cores relativo a melhor potência em cada ponto do grid (melhor entre os dois roteadores)
pcolor(plfSF);title(['Sistema sem Laço - tempo ' num2str(tempoSemFor)]);
% Out:
% Tempo sem Laço FOR = 0.005705

% %% [markdown]
% Além do código ser bem menor (em termos de número de linhas), se percebe uma difereça significativa de tempo de execução sem o uso do laço FOR.
%
% Essa diferença de desempenho é muito mais acentuada quanto maior é o tamanho do laço FOR.
%
% **Passo 6:** Para exemplificar, vamos executar os códigos para um grid de tamanho 5000. Execute in line (via Jupyter Notebook) ou insira o código a seguir no editor do Matlab e salve-o como **handson1_6.m)**:

% %%
clear all;clc;close all;
dPasso = 5;
dDim = 5000;
nl = (dDim-2*dPasso)/dPasso + 1;
%% Código com laço FOR
% Abre contador de tempo
t1 = tic;
% Matriz com posição de cada ponto do grid (posição relativa ao canto inferior direito)
for il = 1:nl 
    for ic = 1:nl
        px(il,ic) = dPasso + (ic-1)*dPasso;
        py(ic,il) = px(il,ic);
    end
end
% Matrizes de posição e potência recebida
for il = 1:nl
    for ic = 1:nl
        % Matrizes com posição de cada ponto do grid relativa a cada
        % roteador
        pbs0(il,ic) = px(il,ic) + j*py(il,ic) - ( dDim/2 + 0.8*dDim*j);
        pbs1(il,ic) = px(il,ic) + j*py(il,ic) - ( dDim/2 + 0.2*dDim*j);
        % Cálculo da potência recebida em cada ponto do grid, recebida de cada roteador
        pl0(il,ic) = 10*log10(1/abs(pbs0(il,ic))^4/1e-3);
        pl1(il,ic) = 10*log10(1/abs(pbs1(il,ic))^4/1e-3);
        % cálculo da melhor potência em cada ponto do grid
        plf(il,ic) = max(pl0(il,ic), pl1(il,ic));
    end
end
% fecha contador de tempo.
tempoComFor = toc(t1);
disp(['Tempo com Laço FOR = ' num2str(tempoComFor)]);
%% Código sem Laço
% Abre contador de tempo
t2 = tic;
% Matriz com posição de cada ponto do grid (posição relativa ao canto inferior direito)
[px,py] = meshgrid(dPasso:dPasso:dDim-dPasso, dPasso:dPasso:dDim-dPasso);
% Matrizes com posição de cada ponto do grid relativa a cada BS
pbs0SF = px + j*py - ( dDim/2 + 0.8*dDim*j);
pbs1SF = px + j*py - ( dDim/2 + 0.2*dDim*j);
% Cálculo da potência recebida em cada roteador
pl0SF = 10*log10(1./(abs(pbs0SF).^4)/1e-3);
pl1SF = 10*log10(1./(abs(pbs1SF).^4)/1e-3);
% Cálculo da melhor potência e cada ponto do grid
plfSF = max(pl0SF,pl1SF);
% fecha contador de tempo 2.
tempoSemFor = toc(t2);
disp(['Tempo sem Laço FOR = ' num2str(tempoSemFor)]);
disp(['Diferença percentual de tempo = ' num2str(( tempoSemFor - tempoComFor )/tempoSemFor*100) ' %']);
% Out:
% Tempo com Laço FOR = 26.9345
% Tempo sem Laço FOR = 0.18058
% Diferença percentual de tempo = -14815.7312 %

% %% [markdown]
% **A diferença percentual é gigantesca e pode fazer toda diferença em projeto grandes que usam o Matlab!!!**
